# %%
# import packages
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

df = pd.read_csv('dataset_19.txt', sep=',', header=None)  # use pandas to read csv file
print('The dataset contains %d rows.' % len(df)) 
df.head() # show first 5 rows of the dataset

# %matplotlib inline

ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

for i in range (0,1):
    df_acc = df[df[24] == i+1].values
    ax1.plot(df_acc[500:1500, 0:3])
    ax2.plot(df_acc[500:1500, 3:6])
#     plt.plot(df_acc[500:1500, 3:6])
    
#     plt.subplot(23,2,(2*i)+1)
#     df_acc = df[df[24] == i+1].values 
#     plt.plot(df_sitting_acc[500:1500, 0:3])
#     plt.subplot(23,2,(2*i)+2)
#     df_gyro = df[df[24] == i+1].values 
#     plt.plot(df_sitting_gyro[500:1500, 3:6])


# plt.subplot(2,2,1)
# df_sitting_acc = df[df[24] == 1].values 
# plt.plot(df_sitting_acc[500:1500, 0:3])
# plt.subplot(2,2,2)
# df_sitting_gyro = df[df[24] == 1].values 
# plt.plot(df_sitting_gyro[500:1500, 3:6])
# plt.subplot(2,2,3)
# df_lying_acc = df[df[24] == 2].values 
# plt.plot(df_lying_acc[500:1500, 0:3])
# plt.subplot(2,2,4)
# df_lying_gyro = df[df[24] == 2].values 
# plt.plot(df_lying_gyro[500:1500, 3:6])
# Out:
# The dataset contains 230628 rows.
